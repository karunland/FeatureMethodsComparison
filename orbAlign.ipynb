# %%
import scipy.misc
import matplotlib.pyplot as plt
import numpy as np
import cv2

image = scipy.misc.ascent()
# plt.imshow(image, cmap="gray")

a = np.asarray(image)
print(a.shape)

fig, ax = plt.subplots()
ax.imshow(a, cmap="gray")
# Out:
# (512, 512)
# /tmp/ipykernel_21114/1071484543.py:6: DeprecationWarning: scipy.misc.ascent has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.ascent instead.
#   image = scipy.misc.ascent()

# %%
import os
#set to 1 to see the compilation going on
os.environ["PYOPENCL_COMPILER_OUTPUT"] = "0"
devicetype="GPU"

from silx.image import sift

sift_ocl = sift.SiftPlan(template=a, devicetype=devicetype)

print("Device used for calculation: ", sift_ocl.ctx.devices[0].name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/karun/alignment-compare/orbAlign.ipynb Cell 2 line 8
#       <a href='vscode-notebook-cell:/home/karun/alignment-compare/orbAlign.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> devicetype="GPU"
#       <a href='vscode-notebook-cell:/home/karun/alignment-compare/orbAlign.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> from silx.image import sift
# ----> <a href='vscode-notebook-cell:/home/karun/alignment-compare/orbAlign.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> sift_ocl = sift.SiftPlan(template=a, devicetype=devicetype)
#      <a href='vscode-notebook-cell:/home/karun/alignment-compare/orbAlign.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> print("Device used for calculation: ", sift_ocl.ctx.devices[0].name)
#
# File ~/.local/lib/python3.10/site-packages/silx/opencl/sift/plan.py:154, in SiftPlan.__init__(self, shape, dtype, template, PIX_PER_KP, init_sigma, ctx, devicetype, platformid, deviceid, block_size, memory, profile)
#     152 self._init_sigma = float(init_sigma)
#     153 memory = self._calc_memory(block_size)
# --> 154 OpenclProcessing.__init__(self, ctx=ctx, devicetype=devicetype,
#     155                           platformid=platformid, deviceid=deviceid,
#     156                           block_size=block_size, profile=profile,
#     157                           memory=memory)
#     158 # TODO WORKGROUP ....
#     159 self.kernels_wg = {}
#
# File ~/.local/lib/python3.10/site-packages/silx/opencl/processing.py:143, in OpenclProcessing.__init__(self, ctx, devicetype, platformid, deviceid, block_size, memory, profile)
#     141     self.ctx = ctx
#     142 else:
# --> 143     self.ctx = ocl.create_context(devicetype=devicetype,
#     144                                   platformid=platformid, deviceid=deviceid,
#     145                                   memory=memory)
#     146 device_name = self.ctx.devices[0].name.strip()
#     147 platform_name = self.ctx.devices[0].platform.name.strip()
#
# AttributeError: 'NoneType' object has no attribute 'create_context'
