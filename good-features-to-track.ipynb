# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('./images/george1e.jpg')
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
corners = cv.goodFeaturesToTrack(gray,25,0.01,10)
corners = np.int0(corners)
for i in corners:
    x,y = i.ravel()
    cv.circle(img,(x,y),10,255,-1)

plt.figure(figsize=(20,10))
plt.imshow(img),plt.show()
# Out:
# /tmp/ipykernel_13128/480330454.py:7: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)
# (<matplotlib.image.AxesImage at 0x7ff2a742e470>, None)
